# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df[df.SalePrice >= 181500].SalePrice = 0
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9880\46851838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.SalePrice >= 181500].SalePrice = 0

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.SalePrice[df.SalePrice >= 181500] = 0
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9880\3209671712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SalePrice[df.SalePrice >= 181500] = 0

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.loc[df.SalePrice >= 181500, "SalePrice"] = 0

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
temp = df.loc[df.SalePrice >= 181500]

# %%
temp.loc[:, "SalePrice"] = 0

# %%
temp
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
# ...

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df1 = pd.DataFrame(data = {"a": [1,2,1,2,1,2], "b": [3,4,3,4,3,4]})
df2 = pd.DataFrame(data = {"a": [1,3,1,3,1], "b": [5,4,5,4,5]})

# %%
df1
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 2  1  3
# 3  2  4
# 4  1  3
# 5  2  4

# %%
df2
# Out:
#    a  b
# 0  1  5
# 1  3  4
# 2  1  5
# 3  3  4
# 4  1  5

# %%
result = pd.concat([df1, df2])
result
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 2  1  3
# 3  2  4
# 4  1  3
# 5  2  4
# 0  1  5
# 1  3  4
# 2  1  5
# 3  3  4
# 4  1  5

# %%
result.loc[0]
# Out:
#    a  b
# 0  1  3
# 0  1  5

# %%
result.reset_index()
# Out:
#     index  a  b
# 0       0  1  3
# 1       1  2  4
# 2       2  1  3
# 3       3  2  4
# 4       4  1  3
# 5       5  2  4
# 6       0  1  5
# 7       1  3  4
# 8       2  1  5
# 9       3  3  4
# 10      4  1  5

# %%
result.reset_index(drop=True)
# Out:
#     a  b
# 0   1  3
# 1   2  4
# 2   1  3
# 3   2  4
# 4   1  3
# 5   2  4
# 6   1  5
# 7   3  4
# 8   1  5
# 9   3  4
# 10  1  5

# %%
result
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 2  1  3
# 3  2  4
# 4  1  3
# 5  2  4
# 0  1  5
# 1  3  4
# 2  1  5
# 3  3  4
# 4  1  5

# %%
result.reset_index(drop=True, inplace=True)

# %%
result
# Out:
#     a  b
# 0   1  3
# 1   2  4
# 2   1  3
# 3   2  4
# 4   1  3
# 5   2  4
# 6   1  5
# 7   3  4
# 8   1  5
# 9   3  4
# 10  1  5

# %%
df2["c"] = 1

# %%
df2
# Out:
#    a  b  c
# 0  1  5  1
# 1  3  4  1
# 2  1  5  1
# 3  3  4  1
# 4  1  5  1

# %%
pd.concat([df1, df2])
# Out:
#    a  b    c
# 0  1  3  NaN
# 1  2  4  NaN
# 2  1  3  NaN
# 3  2  4  NaN
# 4  1  3  NaN
# 5  2  4  NaN
# 0  1  5  1.0
# 1  3  4  1.0
# 2  1  5  1.0
# 3  3  4  1.0
# 4  1  5  1.0

# %%
pd.concat([df1, df2, df1, df2])
# Out:
#    a  b    c
# 0  1  3  NaN
# 1  2  4  NaN
# 2  1  3  NaN
# 3  2  4  NaN
# 4  1  3  NaN
# 5  2  4  NaN
# 0  1  5  1.0
# 1  3  4  1.0
# 2  1  5  1.0
# 3  3  4  1.0
# 4  1  5  1.0
# 0  1  3  NaN
# 1  2  4  NaN
# 2  1  3  NaN
# 3  2  4  NaN
# 4  1  3  NaN
# 5  2  4  NaN
# 0  1  5  1.0
# 1  3  4  1.0
# 2  1  5  1.0
# 3  3  4  1.0
# 4  1  5  1.0

# %%
df1 = pd.DataFrame(data = {"a": [1,2,1,2,1,2], "b": [3,4,3,4,3,4]})
df2 = pd.DataFrame(data = {"c": [1,3,1,3,1], "d": [5,4,5,4,5]})

# %%
df1
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 2  1  3
# 3  2  4
# 4  1  3
# 5  2  4

# %%
df2
# Out:
#    c  d
# 0  1  5
# 1  3  4
# 2  1  5
# 3  3  4
# 4  1  5

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    a  b    c    d
# 0  1  3  1.0  5.0
# 1  2  4  3.0  4.0
# 2  1  3  1.0  5.0
# 3  2  4  3.0  4.0
# 4  1  3  1.0  5.0
# 5  2  4  NaN  NaN

# %%
df1 = pd.DataFrame({
    "first": [1,1,1,1],
    "second": [1,1,1,1],
    "third": [1,2,1,2],
    }, index=[1,2,3,4])

df2 = pd.DataFrame({
    "first": [2,2,2,2],
    "second": [2,2,2,2],
    "fourth": [1,3,1,3]
    }, index=[3,4,5,6])

# %%
df1
# Out:
#    first  second  third
# 1      1       1      1
# 2      1       1      2
# 3      1       1      1
# 4      1       1      2

# %%
df2
# Out:
#    first  second  fourth
# 3      2       2       1
# 4      2       2       3
# 5      2       2       1
# 6      2       2       3

# %%
pd.concat([df1, df2], axis=1, join="outer")
# Out:
#    first  second  third  first  second  fourth
# 1    1.0     1.0    1.0    NaN     NaN     NaN
# 2    1.0     1.0    2.0    NaN     NaN     NaN
# 3    1.0     1.0    1.0    2.0     2.0     1.0
# 4    1.0     1.0    2.0    2.0     2.0     3.0
# 5    NaN     NaN    NaN    2.0     2.0     1.0
# 6    NaN     NaN    NaN    2.0     2.0     3.0

# %%
pd.concat([df1, df2], axis=1, join="inner")
# Out:
#    first  second  third  first  second  fourth
# 3      1       1      1      2       2       1
# 4      1       1      2      2       2       3

# %%
pd.concat([df1, df2], axis=0, join="inner")
# Out:
#    first  second
# 1      1       1
# 2      1       1
# 3      1       1
# 4      1       1
# 3      2       2
# 4      2       2
# 5      2       2
# 6      2       2

# %%
df1.join(df2, rsuffix="_second", how="left")
# Out:
#    first  second  third  first_second  second_second  fourth
# 1      1       1      1           NaN            NaN     NaN
# 2      1       1      2           NaN            NaN     NaN
# 3      1       1      1           2.0            2.0     1.0
# 4      1       1      2           2.0            2.0     3.0

# %%
df1.join(df2, rsuffix="_second", how="right")
# Out:
#    first  second  third  first_second  second_second  fourth
# 3    1.0     1.0    1.0             2              2       1
# 4    1.0     1.0    2.0             2              2       3
# 5    NaN     NaN    NaN             2              2       1
# 6    NaN     NaN    NaN             2              2       3

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.isna()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.isna().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtCond          37
# BsmtQual          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# Condition2         0
# dtype: int64

# %%
df["Alley"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1455    NaN
# 1456    NaN
# 1457    NaN
# 1458    NaN
# 1459    NaN
# Name: Alley, Length: 1460, dtype: object

# %%
df["Alley"].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
df["Alley"].value_counts(dropna=False)
# Out:
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: count, dtype: int64

# %%
df["GarageArea"]
# Out:
# 0       548
# 1       460
# 2       608
# 3       642
# 4       836
#        ...
# 1455    460
# 1456    500
# 1457    252
# 1458    240
# 1459    276
# Name: GarageArea, Length: 1460, dtype: int64

# %%
df["GarageArea"].fillna(0)
# Out:
# 0       548
# 1       460
# 2       608
# 3       642
# 4       836
#        ...
# 1455    460
# 1456    500
# 1457    252
# 1458    240
# 1459    276
# Name: GarageArea, Length: 1460, dtype: int64

# %%
df["GarageArea"].isna().sum()
# Out:
# np.int64(0)
