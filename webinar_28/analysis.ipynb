# %%
import pandas as pd

# %%
import numpy as np

# %%
np.random.seed(42)
df = pd.DataFrame({
    "city": ["Bratislava", "Košice", "Žilina", "Bratislava", "Košice", "Žilina"],
    "year": [2023, 2023, 2023, 2024, 2024, 2024],
    "sales": np.random.randint(5, 200, size=6),
    "cost": np.random.randint(20, 150, size=6)
}, index=["A", "A", "B", "B", "B", "C"])

# %%
df
# Out:
#          city  year  sales  cost
# A  Bratislava  2023    107    40
# A      Košice  2023    184   122
# B      Žilina  2023     97   141
# B  Bratislava  2024     19    94
# B      Košice  2024    111   107
# C      Žilina  2024     76   136

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.loc["A"]
# Out:
#          city  year  sales  cost
# A  Bratislava  2023    107    40
# A      Košice  2023    184   122

# %%
df.loc["A", "city"]
# Out:
# A    Bratislava
# A        Košice
# Name: city, dtype: object

# %%
df.iloc[0]
# Out:
# city     Bratislava
# year           2023
# sales           107
# cost             40
# Name: A, dtype: object

# %%
df.iloc[:2]
# Out:
#          city  year  sales  cost
# A  Bratislava  2023    107    40
# A      Košice  2023    184   122

# %%
df.loc["A":"C", "city"]
# Out:
# A    Bratislava
# A        Košice
# B        Žilina
# B    Bratislava
# B        Košice
# C        Žilina
# Name: city, dtype: object

# %%
df.loc["A":"C", "city":"cost"]
# Out:
#          city  year  sales  cost
# A  Bratislava  2023    107    40
# A      Košice  2023    184   122
# B      Žilina  2023     97   141
# B  Bratislava  2024     19    94
# B      Košice  2024    111   107
# C      Žilina  2024     76   136

# %%
 df.loc[["A", "C"], ["city", "sales"]]
# Out:
#          city  sales
# A  Bratislava    107
# A      Košice    184
# C      Žilina     76

# %%
df.loc[["A", "C"], :"sales"]
# Out:
#          city  year  sales
# A  Bratislava  2023    107
# A      Košice  2023    184
# C      Žilina  2024     76

# %%
df.iloc[:-1]
# Out:
#          city  year  sales  cost
# A  Bratislava  2023    107    40
# A      Košice  2023    184   122
# B      Žilina  2023     97   141
# B  Bratislava  2024     19    94
# B      Košice  2024    111   107

# %%
df["sales"] > 100
# Out:
# A     True
# A     True
# B    False
# B    False
# B     True
# C    False
# Name: sales, dtype: bool

# %%
df.loc[df["sales"] > 100]
# Out:
#          city  year  sales  cost
# A  Bratislava  2023    107    40
# A      Košice  2023    184   122
# B      Košice  2024    111   107

# %%
df = pd.read_csv("train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
pwd
# Out:
# 'C:\\Users\\User\\Documents\\Python_academy_skillmea'

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.iloc[:5]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.iloc[-5:]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.iloc[10]
# Out:
# Id                   11
# MSSubClass           20
# MSZoning             RL
# LotFrontage        70.0
# LotArea           11200
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        129500
# Name: 10, Length: 81, dtype: object

# %%
df.loc[10]
# Out:
# Id                   11
# MSSubClass           20
# MSZoning             RL
# LotFrontage        70.0
# LotArea           11200
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        129500
# Name: 10, Length: 81, dtype: object

# %%
df.loc[:,"SaleCondition"]
# Out:
# 0        Normal
# 1        Normal
# 2        Normal
# 3       Abnorml
# 4        Normal
#          ...
# 1455     Normal
# 1456     Normal
# 1457     Normal
# 1458     Normal
# 1459     Normal
# Name: SaleCondition, Length: 1460, dtype: object

# %%
df.loc[:,["SaleCondition"]]
# Out:
#      SaleCondition
# 0           Normal
# 1           Normal
# 2           Normal
# 3          Abnorml
# 4           Normal
# ...            ...
# 1455        Normal
# 1456        Normal
# 1457        Normal
# 1458        Normal
# 1459        Normal
#
# [1460 rows x 1 columns]

# %%
df.iloc[:,2]
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object

# %%
df.loc[5:15]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# 12  13          20       RL          NaN    12968   Pave   NaN      IR2
# 13  14          20       RL         91.0    10652   Pave   NaN      IR1
# 14  15          20       RL          NaN    10920   Pave   NaN      IR1
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
df.iloc[5:15]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# 12  13          20       RL          NaN    12968   Pave   NaN      IR2
# 13  14          20       RL         91.0    10652   Pave   NaN      IR1
# 14  15          20       RL          NaN    10920   Pave   NaN      IR1
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 5          Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# ...

# %%
df.loc[[3, 5, 7], ["MSZoning", "Street","LandContour"]]
# Out:
#   MSZoning Street LandContour
# 3       RL   Pave         Lvl
# 5       RL   Pave         Lvl
# 7       RL   Pave         Lvl

# %%
df.loc[[3, 5, 7]].iloc[:, :3]
# Out:
#    Id  MSSubClass MSZoning
# 3   4          70       RL
# 5   6          50       RL
# 7   8          60       RL

# %%
df["YrSold"] == 2009
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: YrSold, Length: 1460, dtype: bool

# %%
df.loc[df["YrSold"] == 2009]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg
# 25      26          20       RL        110.0    14230   Pave   NaN      Reg
# 36      37          20       RL        112.0    10859   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
#
# ...

# %%
df.loc[df["YrSold"] == 2009].iloc[::3]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 25      26          20       RL        110.0    14230   Pave   NaN      Reg
# 46      47          50       RL         48.0    12822   Pave   NaN      IR1
# 64      65          60       RL          NaN     9375   Pave   NaN      Reg
# 79      80          50       RM         60.0    10440   Pave  Grvl      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1406  1407          85       RL         70.0     8445   Pave   NaN      Reg
# 1411  1412          50       RL         80.0     9600   Pave   NaN      Reg
# 1415  1416         120       RL         51.0     3635   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
#
# ...

# %%
df.sort_values("LotArea")
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 489    490         180       RM         21.0     1526   Pave   NaN      Reg
# 1038  1039         160       RM         21.0     1533   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
#
# ...

# %%
df.sort_values("LotArea", ascending=True)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 489    490         180       RM         21.0     1526   Pave   NaN      Reg
# 1038  1039         160       RM         21.0     1533   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
#
# ...

# %%
df.sort_values("LotArea", ascending=False)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 489    490         180       RM         21.0     1526   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
#
# ...

# %%
df.sort_values("LotArea", ascending=False).iloc[:5].loc[:, ["MSZoning", "SalePrice", "LotArea"]]
# Out:
#     MSZoning  SalePrice  LotArea
# 313       RL     375000   215245
# 335       RL     228950   164660
# 249       RL     277000   159000
# 706       RL     302000   115149
# 451       RL     280000    70761

# %%
df.loc[:, "MSZoning"] = 1
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60        1         65.0     8450   Pave   NaN      Reg
# 1        2          20        1         80.0     9600   Pave   NaN      Reg
# 2        3          60        1         68.0    11250   Pave   NaN      IR1
# 3        4          70        1         60.0     9550   Pave   NaN      IR1
# 4        5          60        1         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60        1         62.0     7917   Pave   NaN      Reg
# 1456  1457          20        1         85.0    13175   Pave   NaN      Reg
# 1457  1458          70        1         66.0     9042   Pave   NaN      Reg
# 1458  1459          20        1         68.0     9717   Pave   NaN      Reg
# 1459  1460          20        1         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.loc[:, "MSZoning"] = pd.Series(list(range(1, 6)))
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60      1.0         65.0     8450   Pave   NaN      Reg
# 1        2          20      2.0         80.0     9600   Pave   NaN      Reg
# 2        3          60      3.0         68.0    11250   Pave   NaN      IR1
# 3        4          70      4.0         60.0     9550   Pave   NaN      IR1
# 4        5          60      5.0         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60      NaN         62.0     7917   Pave   NaN      Reg
# 1456  1457          20      NaN         85.0    13175   Pave   NaN      Reg
# 1457  1458          70      NaN         66.0     9042   Pave   NaN      Reg
# 1458  1459          20      NaN         68.0     9717   Pave   NaN      Reg
# 1459  1460          20      NaN         75.0     9937   Pave   NaN      Reg
#
# ...
