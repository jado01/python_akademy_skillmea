# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df["X"] = 0

# %%
df["X"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1455    0
# 1456    0
# 1457    0
# 1458    0
# 1459    0
# Name: X, Length: 1460, dtype: int64

# %%
df["X"] = list(range(0, 1460))

# %%
df.X
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1455    1455
# 1456    1456
# 1457    1457
# 1458    1458
# 1459    1459
# Name: X, Length: 1460, dtype: int64

# %%
df["Y"] = pd.Series(list(range(0, 1459)))

# %%
df.Y
# Out:
# 0          0.0
# 1          1.0
# 2          2.0
# 3          3.0
# 4          4.0
#          ...
# 1455    1455.0
# 1456    1456.0
# 1457    1457.0
# 1458    1458.0
# 1459       NaN
# Name: Y, Length: 1460, dtype: float64

# %%
df["LotArea_sqm"] = df["LotArea"] * 0.092903

# %%
df[["LotArea_sqm", "LotArea"]]
# Out:
#       LotArea_sqm  LotArea
# 0      785.030350     8450
# 1      891.868800     9600
# 2     1045.158750    11250
# 3      887.223650     9550
# 4     1324.796780    14260
# ...           ...      ...
# 1455   735.513051     7917
# 1456  1223.997025    13175
# 1457   840.028926     9042
# 1458   902.738451     9717
# 1459   923.177111     9937
#
# [1460 rows x 2 columns]

# %%
df[["LotArea_sqm", "LotArea"]].sort_values("LotArea_sqm")
# Out:
#        LotArea_sqm  LotArea
# 956     120.773900     1300
# 1039    137.217731     1477
# 614     138.518373     1491
# 489     141.769978     1526
# 1038    142.420299     1533
# ...            ...      ...
# 451    6573.909183    70761
# 706   10697.687547   115149
# 249   14771.577000   159000
# 335   15297.407980   164660
# 313   19996.906235   215245
#
# [1460 rows x 2 columns]

# %%
def is_big(value):
    if value > 9000:
        return "Big"
    else:
        return "Small"
        
df["LotArea"].apply(is_big)
# Out:
# 0       Small
# 1         Big
# 2         Big
# 3         Big
# 4         Big
#         ...
# 1455    Small
# 1456      Big
# 1457      Big
# 1458      Big
# 1459      Big
# Name: LotArea, Length: 1460, dtype: object

# %%
df["LotArea"].apply(lambda value: "Big" if value > 9000 else "Small")
# Out:
# 0       Small
# 1         Big
# 2         Big
# 3         Big
# 4         Big
#         ...
# 1455    Small
# 1456      Big
# 1457      Big
# 1458      Big
# 1459      Big
# Name: LotArea, Length: 1460, dtype: object

# %%
df["Is_Big"] = np.where(df["LotArea"] > 9000, "Big", "Small")

# %%
df["Is_Big"]
# Out:
# 0       Small
# 1         Big
# 2         Big
# 3         Big
# 4         Big
#         ...
# 1455    Small
# 1456      Big
# 1457      Big
# 1458      Big
# 1459      Big
# Name: Is_Big, Length: 1460, dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', 'X', 'Y', 'LotArea_sqm', 'Is_Big'],
#       dtype='object')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... MiscVal MoSold YrSold SaleType SaleCondition  \
# 0         Lvl    AllPub  ...       0      2   2008       WD        Normal
# 1         Lvl    AllPub  ...       0      5   2007       WD        Normal
# 2         Lvl    AllPub  ...       0      9   2008       WD        Normal
# 3         Lvl    AllPub  ...       0      2   2006       WD       Abnorml
# 4         Lvl    AllPub  ...       0     12   2008       WD        Normal
#
#   SalePrice  X    Y  LotArea_sqm  Is_Big
# 0    208500  0  0.0    785.03035   Small
# 1    181500  1  1.0    891.86880     Big
# 2    223500  2  2.0   1045.15875     Big
# 3    140000  3  3.0    887.22365     Big
# 4    250000  4  4.0   1324.79678     Big
#
# [5 rows x 85 columns]

# %%
df.assign(
    LotArea_sqm = df["LotArea"] * 0.092903,
    z = 1,
    yy = 1
)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... YrSold SaleType SaleCondition SalePrice     X  \
# 0            Lvl    AllPub  ...   2008       WD        Normal    208500     0
# 1            Lvl    AllPub  ...   2007       WD        Normal    181500     1
# 2            Lvl    AllPub  ...   2008       WD        Normal    223500     2
# 3            Lvl    AllPub  ...   2006       WD       Abnorml    140000     3
# 4            Lvl    AllPub  ...   2008       WD        Normal    250000     4
# ...          ...       ...  ...    ...      ...           ...       ...   ...
# 1455         Lvl    AllPub  ...   2007       WD        Normal    175000  1455
# 1456         Lvl    AllPub  ...   2010       WD        Normal    210000  1456
# 1457         Lvl    AllPub  ...   2010       WD        Normal    266500  1457
# 1458         Lvl    AllPub  ...   2010       WD        Normal    142125  1458
# 1459         Lvl    AllPub  ...   2008       WD        Normal    147500  1459
#
#            Y  LotArea_sqm  Is_Big  z  yy
# 0        0.0   785.030350   Small  1   1
# 1        1.0   891.868800     Big  1   1
# 2        2.0  1045.158750     Big  1   1
# 3        3.0   887.223650     Big  1   1
# 4        4.0  1324.796780     Big  1   1
# ...      ...          ...     ... ..  ..
# 1455  1455.0   735.513051   Small  1   1
# 1456  1456.0  1223.997025     Big  1   1
# 1457  1457.0   840.028926     Big  1   1
# 1458  1458.0   902.738451     Big  1   1
# 1459     NaN   923.177111     Big  1   1
#
# [1460 rows x 87 columns]

# %%
data = {
    "MSSubClass": [20, 60, 70],
    "MSZoning": ["RL", "RM", "RL"],
    "LotArea": [8450, 9600, 11250],
    "Street": ["Pave", "Pave", "Grvl"],
    "Neighborhood": ["CollgCr", "Veenker", "Crawfor"],
    "SalePrice": [208500, 181500, 223500]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    MSSubClass MSZoning  LotArea Street Neighborhood  SalePrice
# 0          20       RL     8450   Pave      CollgCr     208500
# 1          60       RM     9600   Pave      Veenker     181500
# 2          70       RL    11250   Grvl      Crawfor     223500

# %%
new_house = {
    "MSSubClass": 20,
    "MSZoning": "RL",
    "LotArea": 10000,
    "Street": "Pave",
    "Neighborhood": "CollgCr",
    "SalePrice": 200000
}

# %%
df.loc[0] = new_house

# %%
df
# Out:
#     MSSubClass MSZoning  LotArea Street Neighborhood  SalePrice
# 0           20       RL    10000   Pave      CollgCr     200000
# 1           60       RM     9600   Pave      Veenker     181500
# 2           70       RL    11250   Grvl      Crawfor     223500
# 10          20       RL    10000   Pave      CollgCr     200000

# %%
df.shape
# Out:
# (4, 6)

# %%
 df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#    MSSubClass MSZoning  LotArea Street Neighborhood  SalePrice
# 0          20       RL    10000   Pave      CollgCr     200000
# 1          60       RM     9600   Pave      Veenker     181500
# 2          70       RL    11250   Grvl      Crawfor     223500
# 3          20       RL    10000   Pave      CollgCr     200000

# %%
df
# Out:
#    MSSubClass MSZoning  LotArea Street Neighborhood  SalePrice
# 0          20       RL    10000   Pave      CollgCr     200000
# 1          60       RM     9600   Pave      Veenker     181500
# 2          70       RL    11250   Grvl      Crawfor     223500
# 3          20       RL    10000   Pave      CollgCr     200000

# %%
df.drop(columns=["Street"])
# Out:
#    MSSubClass MSZoning  LotArea Neighborhood  SalePrice
# 0          20       RL    10000      CollgCr     200000
# 1          60       RM     9600      Veenker     181500
# 2          70       RL    11250      Crawfor     223500
# 3          20       RL    10000      CollgCr     200000

# %%
df
# Out:
#    MSSubClass MSZoning  LotArea Street Neighborhood  SalePrice
# 0          20       RL    10000   Pave      CollgCr     200000
# 1          60       RM     9600   Pave      Veenker     181500
# 2          70       RL    11250   Grvl      Crawfor     223500
# 3          20       RL    10000   Pave      CollgCr     200000

# %%
df.drop(columns=["Street"], inplace=True)

# %%
df
# Out:
#    MSSubClass MSZoning  LotArea Neighborhood  SalePrice
# 0          20       RL    10000      CollgCr     200000
# 1          60       RM     9600      Veenker     181500
# 2          70       RL    11250      Crawfor     223500
# 3          20       RL    10000      CollgCr     200000

# %%
df.drop(["MSSubClass"], axis=1)
# Out:
#   MSZoning  LotArea Neighborhood  SalePrice
# 0       RL    10000      CollgCr     200000
# 1       RM     9600      Veenker     181500
# 2       RL    11250      Crawfor     223500
# 3       RL    10000      CollgCr     200000

# %%
df
# Out:
#    MSSubClass MSZoning  LotArea Neighborhood  SalePrice
# 0          20       RL    10000      CollgCr     200000
# 1          60       RM     9600      Veenker     181500
# 2          70       RL    11250      Crawfor     223500
# 3          20       RL    10000      CollgCr     200000

# %%
df.drop([0], axis=0)
# Out:
#    MSSubClass MSZoning  LotArea Neighborhood  SalePrice
# 1          60       RM     9600      Veenker     181500
# 2          70       RL    11250      Crawfor     223500
# 3          20       RL    10000      CollgCr     200000

# %%
del df["LotArea"]

# %%
df
# Out:
#    MSSubClass MSZoning Neighborhood  SalePrice
# 0          20       RL      CollgCr     200000
# 1          60       RM      Veenker     181500
# 2          70       RL      Crawfor     223500
# 3          20       RL      CollgCr     200000

# %%
df.pop("SalePrice")
# Out:
# 0    200000
# 1    181500
# 2    223500
# 3    200000
# Name: SalePrice, dtype: int64
