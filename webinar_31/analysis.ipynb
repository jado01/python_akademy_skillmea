# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# Name: count, dtype: int64

# %%
df_numberic = df.loc[:, (df.dtypes == np.int64) | (df.dtypes == np.float64)]

# %%
df_numberic
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
df_object = df.loc[:, ~(df.dtypes == np.int64) | (df.dtypes == np.float64)]

# %%
df_object
# Out:
#      MSZoning  LotFrontage Street Alley LotShape LandContour Utilities  \
# 0          RL         65.0   Pave   NaN      Reg         Lvl    AllPub
# 1          RL         80.0   Pave   NaN      Reg         Lvl    AllPub
# 2          RL         68.0   Pave   NaN      IR1         Lvl    AllPub
# 3          RL         60.0   Pave   NaN      IR1         Lvl    AllPub
# 4          RL         84.0   Pave   NaN      IR1         Lvl    AllPub
# ...       ...          ...    ...   ...      ...         ...       ...
# 1455       RL         62.0   Pave   NaN      Reg         Lvl    AllPub
# 1456       RL         85.0   Pave   NaN      Reg         Lvl    AllPub
# 1457       RL         66.0   Pave   NaN      Reg         Lvl    AllPub
# 1458       RL         68.0   Pave   NaN      Reg         Lvl    AllPub
# 1459       RL         75.0   Pave   NaN      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageYrBlt GarageFinish  \
# ...

# %%
df["Alley"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1455    NaN
# 1456    NaN
# 1457    NaN
# 1458    NaN
# 1459    NaN
# Name: Alley, Length: 1460, dtype: object

# %%
df["Alley"].isna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1455    True
# 1456    True
# 1457    True
# 1458    True
# 1459    True
# Name: Alley, Length: 1460, dtype: bool

# %%
df["Alley"].notna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: Alley, Length: 1460, dtype: bool

# %%
any(df["Alley"].notna())
# Out:
# True

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
df.dropna(axis=1)
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
df_numberic
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
df_numberic.isna()
# Out:
#          Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     False       False        False    False        False        False
# 1     False       False        False    False        False        False
# 2     False       False        False    False        False        False
# 3     False       False        False    False        False        False
# 4     False       False        False    False        False        False
# ...     ...         ...          ...      ...          ...          ...
# 1455  False       False        False    False        False        False
# 1456  False       False        False    False        False        False
# 1457  False       False        False    False        False        False
# 1458  False       False        False    False        False        False
# 1459  False       False        False    False        False        False
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
df_numberic.isna().apply(any)
# Out:
# Id               False
# MSSubClass       False
# LotFrontage       True
# LotArea          False
# OverallQual      False
# OverallCond      False
# YearBuilt        False
# YearRemodAdd     False
# MasVnrArea        True
# BsmtFinSF1       False
# BsmtFinSF2       False
# BsmtUnfSF        False
# TotalBsmtSF      False
# 1stFlrSF         False
# 2ndFlrSF         False
# LowQualFinSF     False
# GrLivArea        False
# BsmtFullBath     False
# BsmtHalfBath     False
# FullBath         False
# HalfBath         False
# BedroomAbvGr     False
# KitchenAbvGr     False
# TotRmsAbvGrd     False
# Fireplaces       False
# GarageYrBlt       True
# GarageCars       False
# GarageArea       False
# WoodDeckSF       False
# OpenPorchSF      False
# EnclosedPorch    False
# 3SsnPorch        False
# ScreenPorch      False
# PoolArea         False
# MiscVal          False
# MoSold           False
# YrSold           False
# SalePrice        False
# dtype: bool

# %%
df["GarageYrBlt"].plot()
# Out:
# <Axes: >

# %%
df["GarageYrBlt"].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: GarageYrBlt, Length: 1460, dtype: bool

# %%
df.loc[df["GarageYrBlt"].isna(), "GarageYrBlt"]
# Out:
# 39     NaN
# 48     NaN
# 78     NaN
# 88     NaN
# 89     NaN
#         ..
# 1349   NaN
# 1407   NaN
# 1449   NaN
# 1450   NaN
# 1453   NaN
# Name: GarageYrBlt, Length: 81, dtype: float64

# %%
df.loc[df["GarageYrBlt"].isna(), "GarageYrBlt"] = df["GarageYrBlt"].mean()

# %%
df.loc[df["GarageYrBlt"].isna(), "GarageYrBlt"]
# Out:
# Series([], Name: GarageYrBlt, dtype: float64)

# %%
df.groupby("Neighborhood")

# %%
df.groupby("Neighborhood")["SalePrice"]

# %%
df.groupby("Neighborhood")["SalePrice"].mean()
# Out:
# Neighborhood
# Blmngtn    194870.882353
# Blueste    137500.000000
# BrDale     104493.750000
# BrkSide    124834.051724
# ClearCr    212565.428571
# CollgCr    197965.773333
# Crawfor    210624.725490
# Edwards    128219.700000
# Gilbert    192854.506329
# IDOTRR     100123.783784
# MeadowV     98576.470588
# Mitchel    156270.122449
# NAmes      145847.080000
# NPkVill    142694.444444
# NWAmes     189050.068493
# NoRidge    335295.317073
# NridgHt    316270.623377
# OldTown    128225.300885
# SWISU      142591.360000
# Sawyer     136793.135135
# SawyerW    186555.796610
# Somerst    225379.837209
# StoneBr    310499.000000
# Timber     242247.447368
# Veenker    238772.727273
# Name: SalePrice, dtype: float64

# %%
df.groupby("Neighborhood", as_index=False)["SalePrice"].mean()
# Out:
#    Neighborhood      SalePrice
# 0       Blmngtn  194870.882353
# 1       Blueste  137500.000000
# 2        BrDale  104493.750000
# 3       BrkSide  124834.051724
# 4       ClearCr  212565.428571
# 5       CollgCr  197965.773333
# 6       Crawfor  210624.725490
# 7       Edwards  128219.700000
# 8       Gilbert  192854.506329
# 9        IDOTRR  100123.783784
# 10      MeadowV   98576.470588
# 11      Mitchel  156270.122449
# 12        NAmes  145847.080000
# 13      NPkVill  142694.444444
# 14       NWAmes  189050.068493
# 15      NoRidge  335295.317073
# 16      NridgHt  316270.623377
# 17      OldTown  128225.300885
# 18        SWISU  142591.360000
# 19       Sawyer  136793.135135
# 20      SawyerW  186555.796610
# 21      Somerst  225379.837209
# 22      StoneBr  310499.000000
# 23       Timber  242247.447368
# 24      Veenker  238772.727273

# %%
df.groupby("Neighborhood")["SalePrice"].mean().reset_index()
# Out:
#    Neighborhood      SalePrice
# 0       Blmngtn  194870.882353
# 1       Blueste  137500.000000
# 2        BrDale  104493.750000
# 3       BrkSide  124834.051724
# 4       ClearCr  212565.428571
# 5       CollgCr  197965.773333
# 6       Crawfor  210624.725490
# 7       Edwards  128219.700000
# 8       Gilbert  192854.506329
# 9        IDOTRR  100123.783784
# 10      MeadowV   98576.470588
# 11      Mitchel  156270.122449
# 12        NAmes  145847.080000
# 13      NPkVill  142694.444444
# 14       NWAmes  189050.068493
# 15      NoRidge  335295.317073
# 16      NridgHt  316270.623377
# 17      OldTown  128225.300885
# 18        SWISU  142591.360000
# 19       Sawyer  136793.135135
# 20      SawyerW  186555.796610
# 21      Somerst  225379.837209
# 22      StoneBr  310499.000000
# 23       Timber  242247.447368
# 24      Veenker  238772.727273

# %%
df.groupby("Neighborhood").agg(
    n_houses=("SalePrice", "count"),
    avg_price=("SalePrice", "mean")
)
# Out:
#               n_houses      avg_price
# Neighborhood
# Blmngtn             17  194870.882353
# Blueste              2  137500.000000
# BrDale              16  104493.750000
# BrkSide             58  124834.051724
# ClearCr             28  212565.428571
# CollgCr            150  197965.773333
# Crawfor             51  210624.725490
# Edwards            100  128219.700000
# Gilbert             79  192854.506329
# IDOTRR              37  100123.783784
# MeadowV             17   98576.470588
# Mitchel             49  156270.122449
# NAmes              225  145847.080000
# NPkVill              9  142694.444444
# NWAmes              73  189050.068493
# NoRidge             41  335295.317073
# NridgHt             77  316270.623377
# OldTown            113  128225.300885
# SWISU               25  142591.360000
# Sawyer              74  136793.135135
# SawyerW             59  186555.796610
# Somerst             86  225379.837209
# StoneBr             25  310499.000000
# ...

# %%
df.groupby("Neighborhood").agg(
    n_houses=("SalePrice", "count"),
    avg_price=("SalePrice", "mean"),
    median_lot=("LotArea", "median")
)
# Out:
#               n_houses      avg_price  median_lot
# Neighborhood
# Blmngtn             17  194870.882353      3182.0
# Blueste              2  137500.000000      1625.0
# BrDale              16  104493.750000      1680.0
# BrkSide             58  124834.051724      6240.0
# ClearCr             28  212565.428571     17575.0
# CollgCr            150  197965.773333      9356.0
# Crawfor             51  210624.725490     11500.0
# Edwards            100  128219.700000      9091.0
# Gilbert             79  192854.506329      9967.0
# IDOTRR              37  100123.783784      7920.0
# MeadowV             17   98576.470588      1974.0
# Mitchel             49  156270.122449      9947.0
# NAmes              225  145847.080000      9492.0
# NPkVill              9  142694.444444      2308.0
# NWAmes              73  189050.068493     11029.0
# NoRidge             41  335295.317073     12090.0
# NridgHt             77  316270.623377     11694.0
# ...

# %%
df.groupby("Neighborhood").agg(
    n_houses=("SalePrice", "count"),
    avg_price=("SalePrice", "mean"),
    median_lot=("LotArea", "median")
).sort_values("avg_price", ascending=False)
# Out:
#               n_houses      avg_price  median_lot
# Neighborhood
# NoRidge             41  335295.317073     12090.0
# NridgHt             77  316270.623377     11694.0
# StoneBr             25  310499.000000      6820.0
# Timber              38  242247.447368     12781.5
# Veenker             11  238772.727273     11120.0
# Somerst             86  225379.837209      8640.0
# ClearCr             28  212565.428571     17575.0
# Crawfor             51  210624.725490     11500.0
# CollgCr            150  197965.773333      9356.0
# Blmngtn             17  194870.882353      3182.0
# Gilbert             79  192854.506329      9967.0
# NWAmes              73  189050.068493     11029.0
# SawyerW             59  186555.796610      9317.0
# Mitchel             49  156270.122449      9947.0
# NAmes              225  145847.080000      9492.0
# NPkVill              9  142694.444444      2308.0
# SWISU               25  142591.360000      7804.0
# ...

# %%
df.groupby(["MSZoning", "BldgType"])["SalePrice"].mean().reset_index()
# Out:
#    MSZoning BldgType      SalePrice
# 0   C (all)     1Fam   67931.111111
# 1   C (all)   2fmCon  133900.000000
# 2        FV     1Fam  240940.236842
# 3        FV    Twnhs  167533.333333
# 4        FV   TwnhsE  180410.277778
# 5        RH     1Fam  110770.444444
# 6        RH   2fmCon  180000.000000
# 7        RH   Duplex  144666.666667
# 8        RH   TwnhsE  157000.000000
# 9        RL     1Fam  193592.266341
# 10       RL   2fmCon  134662.500000
# 11       RL   Duplex  132379.906977
# 12       RL    Twnhs  178850.000000
# 13       RL   TwnhsE  206653.333333
# 14       RM     1Fam  125436.899281
# 15       RM   2fmCon  111075.000000
# 16       RM   Duplex  136300.000000
# 17       RM    Twnhs  106162.500000
# 18       RM   TwnhsE  146020.000000

# %%
df.groupby("Neighborhood").agg(
    count=("GarageYrBlt", "count"),
    size=("GarageYrBlt", "size"),
)
# Out:
#               count  size
# Neighborhood
# Blmngtn          17    17
# Blueste           2     2
# BrDale           15    16
# BrkSide          48    58
# ClearCr          27    28
# CollgCr         148   150
# Crawfor          51    51
# Edwards          78   100
# Gilbert          79    79
# IDOTRR           29    37
# MeadowV          12    17
# Mitchel          44    49
# NAmes           219   225
# NPkVill           9     9
# NWAmes           73    73
# NoRidge          41    41
# NridgHt          77    77
# OldTown         101   113
# SWISU            20    25
# Sawyer           71    74
# SawyerW          58    59
# Somerst          86    86
# StoneBr          25    25
# Timber           38    38
# Veenker          11    11

# %%
df["NeighborhoodAvgPrice"] = df.groupby("Neighborhood")["SalePrice"].transform("mean")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.groupby("Neighborhood").filter(lambda g: len(g) >= 50)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.groupby("Neighborhood").size()
# Out:
# Neighborhood
# Blmngtn     17
# Blueste      2
# BrDale      16
# BrkSide     58
# ClearCr     28
# CollgCr    150
# Crawfor     51
# Edwards    100
# Gilbert     79
# IDOTRR      37
# MeadowV     17
# Mitchel     49
# NAmes      225
# NPkVill      9
# NWAmes      73
# NoRidge     41
# NridgHt     77
# OldTown    113
# SWISU       25
# Sawyer      74
# SawyerW     59
# Somerst     86
# StoneBr     25
# Timber      38
# Veenker     11
# dtype: int64

# %%
df.groupby("Neighborhood")["SalePrice"].size()
# Out:
# Neighborhood
# Blmngtn     17
# Blueste      2
# BrDale      16
# BrkSide     58
# ClearCr     28
# CollgCr    150
# Crawfor     51
# Edwards    100
# Gilbert     79
# IDOTRR      37
# MeadowV     17
# Mitchel     49
# NAmes      225
# NPkVill      9
# NWAmes      73
# NoRidge     41
# NridgHt     77
# OldTown    113
# SWISU       25
# Sawyer      74
# SawyerW     59
# Somerst     86
# StoneBr     25
# Timber      38
# Veenker     11
# Name: SalePrice, dtype: int64

# %%
df.groupby("Neighborhood")["SalePrice"].mean().sort_values(ascending=False)
# Out:
# Neighborhood
# NoRidge    335295.317073
# NridgHt    316270.623377
# StoneBr    310499.000000
# Timber     242247.447368
# Veenker    238772.727273
# Somerst    225379.837209
# ClearCr    212565.428571
# Crawfor    210624.725490
# CollgCr    197965.773333
# Blmngtn    194870.882353
# Gilbert    192854.506329
# NWAmes     189050.068493
# SawyerW    186555.796610
# Mitchel    156270.122449
# NAmes      145847.080000
# NPkVill    142694.444444
# SWISU      142591.360000
# Blueste    137500.000000
# Sawyer     136793.135135
# OldTown    128225.300885
# Edwards    128219.700000
# BrkSide    124834.051724
# BrDale     104493.750000
# IDOTRR     100123.783784
# MeadowV     98576.470588
# Name: SalePrice, dtype: float64

# %%
df.groupby("MSZoning")["SalePrice"].mean().sort_values(ascending=False)
# Out:
# MSZoning
# FV         214014.061538
# RL         191004.994787
# RH         131558.375000
# RM         126316.830275
# C (all)     74528.000000
# Name: SalePrice, dtype: float64

# %%
df.groupby(["MSZoning", "BldgType"])["SalePrice"].mean().reset_index().sort_values("SalePrice", ascending=False)
# Out:
#    MSZoning BldgType      SalePrice
# 2        FV     1Fam  240940.236842
# 13       RL   TwnhsE  206653.333333
# 9        RL     1Fam  193592.266341
# 4        FV   TwnhsE  180410.277778
# 6        RH   2fmCon  180000.000000
# 12       RL    Twnhs  178850.000000
# 3        FV    Twnhs  167533.333333
# 8        RH   TwnhsE  157000.000000
# 18       RM   TwnhsE  146020.000000
# 7        RH   Duplex  144666.666667
# 16       RM   Duplex  136300.000000
# 10       RL   2fmCon  134662.500000
# 1   C (all)   2fmCon  133900.000000
# 11       RL   Duplex  132379.906977
# 14       RM     1Fam  125436.899281
# 15       RM   2fmCon  111075.000000
# 5        RH     1Fam  110770.444444
# 17       RM    Twnhs  106162.500000
# 0   C (all)     1Fam   67931.111111

# %%
df["NeighborhoodAvgPrice"] = df.groupby("Neighborhood")["SalePrice"].transform("mean")
df["PriceVsAvgNeighborhood"] = df["SalePrice"] - df["NeighborhoodAvgPrice"]

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...
